# %%
# !git clone https://github.com/THUDM/ChatGLM3.git
# Out:
# Cloning into 'ChatGLM3'...
# remote: Enumerating objects: 1474, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 1474 (delta 82), reused 123 (delta 63), pack-reused 1301
# Receiving objects: 100% (1474/1474), 17.75 MiB | 9.73 MiB/s, done.
# Resolving deltas: 100% (822/822), done.

# %%
! pip install deepspeed
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 34.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
pip install -r /content/ChatGLM3/finetune_demo/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 94.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 52.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm3-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm3-6b",trust_remote_code=True, device='cuda')

# 定义保存路径
save_path = "/content/ChatGLM_Model"

# 创建目录（如果不存在）
import os
os.makedirs(save_path, exist_ok=True)

# 保存模型和分词器
tokenizer.save_pretrained(save_path)
model.save_pretrained(save_path)

print("模型保存完成。")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# tokenization_chatglm.py:   0%|          | 0.00/13.0k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - tokenization_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.40.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 62.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ...

# %%
# !python /content/ChatGLM3/finetune_demo/finetune_hf.py  /content/AdvertiseGen_fix  /content/ChatGLM_Model  /content/ChatGLM3/finetune_demo/configs/lora.yaml
# Out:
# 2024-05-30 13:51:59.576473: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 13:51:59.576538: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 13:51:59.578121: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-30 13:52:00.671919: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
/content/drive/My Drive/ColabData/Model_Path

# %%
/content/drive/My Drive/ColabData/checkpoint-3000

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive')

# 复制文件夹到Google Drive
destination_path = '/content/drive/MyDrive/ColabData/ChatGLM_Model/NEW_TRAIN'
source_path = '/content/ChatGLM_Model'

shutil.copytree(source_path, destination_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/ColabData/ChatGLM_Model/NEW_TRAIN'

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive')

# 复制文件夹到Google Drive
destination_path = '/content/model_path'
source_path = '/content/drive/MyDrive/ColabData/ChatGLM_Model/Model_Path'

shutil.copytree(source_path, destination_path)

print(f'Folder saved to {dst_folder}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Folder saved to /content/drive/My Drive/ColabData/Model_Path

# %%
from google.colab import drive
import shutil
import os

# 复制文件夹到Google Drive
destination_path = '/content/drive/MyDrive/ColabData/ChatGLM_Model/NEW_DOWNLOAD_MODEL'
source_path = '/content/ChatGLM_Model'

shutil.copytree(source_path, destination_path)
/content/ChatGLM_Model/model-00002-of-00003.safetensors
# Out:
# '/content/drive/MyDrive/ColabData/ChatGLM_Model/NEW_DOWNLOAD_MODEL'

# %%
# !python /content/ChatGLM3/finetune_demo/inference_hf.py /content/model_output/checkpoint-700 --prompt 你好，你叫什么，主要功能是什么
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.33s/it]
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# 2024-05-30 14:05:54.547539: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 14:05:54.547590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
from pathlib import Path
from typing import Union

from peft import AutoPeftModelForCausalLM, PeftModelForCausalLM
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
    PreTrainedTokenizerFast,
)

ModelType = Union[PreTrainedModel, PeftModelForCausalLM]
TokenizerType = Union[PreTrainedTokenizer, PreTrainedTokenizerFast]


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def load_model_and_tokenizer(model_dir: Union[str, Path]) -> tuple[ModelType, TokenizerType]:
    model_dir = _resolve_path(model_dir)
    if (model_dir / 'adapter_config.json').exists():
        model = AutoPeftModelForCausalLM.from_pretrained(
            model_dir, trust_remote_code=True, device_map='auto'
        )
        tokenizer_dir = model.peft_config['default'].base_model_name_or_path
    else:
        model = AutoModelForCausalLM.from_pretrained(
            model_dir, trust_remote_code=True, device_map='auto'
        )
        tokenizer_dir = model_dir
    tokenizer = AutoTokenizer.from_pretrained(
        tokenizer_dir, trust_remote_code=True
    )
    return model, tokenizer

# %%
model_dir = "/content/checkpoint-3000"
prompt = "你叫什么名字"

model, tokenizer = load_model_and_tokenizer(model_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:transformers_modules.THUDM.chatglm3-6b.6f3b58ec10f088978ae174398f9d20b6dfc71552.tokenization_chatglm:Setting eos_token is not supported, use the default one.
# WARNING:transformers_modules.THUDM.chatglm3-6b.6f3b58ec10f088978ae174398f9d20b6dfc71552.tokenization_chatglm:Setting pad_token is not supported, use the default one.
# ...

# %%
response, _ = model.chat(tokenizer, prompt)
print(response)
# Out:
# 我的名字是FU Generator，，是一个专门用于建筑设计行业的多模态大语言模型。

# %%
prompt = "你是谁"
response, _ = model.chat(tokenizer, prompt, history=None)
print(response)
# Out:
# 我是FU Generator，一款用于建筑设计行业的多模态大语言模型。

# %%
prompt = "你能干什么"
response, _ = model.chat(tokenizer, prompt, history=None)
print(response)
# Out:
# FU Generator主要用于建筑设计领域，帮助专业人士解决设计问题，提供规范建议，并辅助生成设计方案。

# %%
prompt = "你可以回答什么问题"
response, _ = model.chat(tokenizer, prompt, history=None)
print(response)
# Out:
# 我可以回答各种建筑设计相关的问题，包括设计规范、设计方案、建筑规范等。
